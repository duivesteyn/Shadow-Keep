# %% [markdown]
# # Shadow Keep - Map Decoding

# %%
#py
#Shadow Keep - Labyrinth Decoding
# bmd
# 2024-09-08
#
# Decoding the Maps/Dungeons from 1992 Game Shadow Keep
# Really wanted to see everything in these maps, and its really slow to map by hand!
#
# Would like to print it here, work out the codes and then assemble into a picture!

from bmd_skmap_functions import *

map_and_filename = 'map-dwelling'
f2 = open(f"03 ascii/{map_and_filename}.txt", "r") #labyrinth 23400 #Sometimes this doesnt work for the input data. not sure whats going on. but an online hex converter worked great! https://www.rapidtables.com/convert/number/hex-to-ascii.html
map_data_direct_from_ascii = f2.read()
print(len(map_data_direct_from_ascii))
map_data = map_data_direct_from_ascii

print(map_data)
size = len(map_data)
print(size) # Labyrinth Length was 11700 -> this is roughly 108 blocks by 108 - > Not a perfect square. ok that doesnt matter. Answer is going to be around this!
# Out:
# 11700
# ...

# %%
#What are the factors of 11700? -> The map is going to be approximately square-ish.

potential_dimensions = factors(size)
print('All Dimensions:')
print(potential_dimensions)
potential_dimensions_2 = []

for item in potential_dimensions:
    if item > 100 and item < 500:
        potential_dimensions_2.append(item)

print('\nThe likely dimensions are:')
print(potential_dimensions_2)
# Out:
# All Dimensions:
# {1, 2, 3, 4, 5, 6, 900, 390, 9, 10, 650, 12, 13, 780, 15, 130, 1170, 18, 1300, 20, 150, 25, 26, 156, 260, 1950, 30, 2340, 36, 39, 300, 45, 50, 11700, 52, 180, 3900, 60, 65, 450, 195, 325, 585, 75, 78, 975, 468, 5850, 90, 225, 100, 234, 2925, 117}
#
# The likely dimensions are:
# [390, 130, 150, 156, 260, 300, 180, 450, 195, 325, 468, 225, 234, 117]

# %%
# That bottom one of 117x100 is the sort of dimension that seems right.
# Now want to draw the data in lines of x Long, i.e. 117 rows of 100, or 100 rows of 117 long!

def split_string_by_n_chars(input_string, n):
    return [input_string[i:i+n] for i in range(0, len(input_string), n)]

n = 130  # Number of characters per line
output = split_string_by_n_chars(map_data, n)
for line in output: print(line)
# Out:
# D                                   t                                                    wwy    t        t            t
#    y                                             we       y            y          y      t                      A    A
#          wl            y  y        t         y          t         A              A                 wl   qqqqqqqqq   qqqqqqqqq   qq
# qqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq    wiy  qJ  H H q y qH  J  Lq   qJ  ZLZ q   qKK    Hq   qH     Jq   qH  H
#  Jq   qLZ    Hq    wnt  q       q   q      Zq y q       q   q       q   q       q   q       q   qZ      q    wg   qK     Zq   qH
#     q   qH     Kq   qL      q   q      Lq A q      Lq   q      Kq    wsy  q     ZLq   q      Kq t q       q   qZ     Jq   q      Z
# q   q      Zq   q       q    w    q  aaa  q  yq  aaa  q   q  aaa  q  yq  aaa  q   q  aaa  q   q  aaa  q   qJ aaa  q    w    qqqqaq
# ...

# %%
for n in potential_dimensions_2:
    m = 11700/n
    print(f'Printing {n} by {m}')

for n in potential_dimensions_2:
    m = int(11700/n)
    print(f'Printing {m} by {n}') 
    output = split_string_by_n_chars(map_data, m)
    for line in output: print(line)
    print('\n\n')
# Out:
# Printing 390 by 30.0
# Printing 130 by 90.0
# Printing 150 by 78.0
# Printing 156 by 75.0
# Printing 260 by 45.0
# Printing 300 by 39.0
# Printing 180 by 65.0
# Printing 450 by 26.0
# Printing 195 by 60.0
# Printing 325 by 36.0
# Printing 468 by 25.0
# Printing 225 by 52.0
# Printing 234 by 50.0
# Printing 117 by 100.0
# Printing 30 by 390
# D
#       t
#                              w
# wy    t        t            t
#              y
#                              w
# e       y            y
#   y      t
#   A    A                     w
# l            y  y        t
#      y          t         A
#            A                 w
# l   qqqqqqqqq   qqqqqqqqq   qq
# qqqqqqq   qqqqqqqqq   qqqqqqqq
# q   qqqqqqqqq   qqqqqqqqq    w
# iy  qJ  H H q y qH  J  Lq   qJ
#   ZLZ q   qKK    Hq   qH     J
# q   qH  H  Jq   qLZ    Hq    w
# nt  q       q   q      Zq y q
#       q   q       q   q
# q   q       q   qZ      q    w
# g   qK     Zq   qH      q   qH
#      Kq   qL      q   q      L
# ...

# %% [markdown]
# ## This lead to me finding the Labyrinth Map is 90 by 130. This also worked for the cave! (And all other maps)
#
# ❗❗❗ This is the only version with perfectly straight lines down. and makes sense. can even recognise parts of the maze!!❗❗❗
# Unique Chars: {' ', 'y', 'G', 'b', 'a', '$', ':', 'c', 'l'}
#
# - ' ' is empty walking space ❓
# - G is the START & EXIT!!
# - $ is a wall
# - C is treasure!
# - ':' is a scroll that says "dead end"
# - b: ❓❓❓
# - a: ❓❓❓
# - y: ❓❓❓
# - l ❓❓❓
# - w is water!
# - FF ❓❓

# %%
output = split_string_by_n_chars(map_data, 90)
square_data_array = []
square_data_array_2 = []
for line in output: 
    #print(line)
    square_data_array.append(line)

#Split up the data into indiviudla array elements (inc per line)
for line in output:
    line_data = []
    for char in line:
        line_data.append(char)
    square_data_array_2.append(line_data)


special_chars = {'y', 'G', 'b', 'a', ':', 'c', 'l'}

#PRINT DATA VISUALLY
for line in square_data_array:
    for char in line:
        if char in special_chars:
            print(f"\x1b[31m{char}\x1b[0m", end='')
        else:
            print(char, end='')
    print('')
# Out:
# D                                   t                                                    w
# wy    t        t            t              y                                             w
# e       y            y          y      t                      A    A                     w
# l            y  y        t         y          t         A              A                 w
# l   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq    w
# iy  qJ  H H q y qH  J  Lq   qJ  ZLZ q   qKK    Hq   qH     Jq   qH  H  Jq   qLZ    Hq    w
# nt  q       q   q      Zq y q       q   q       q   q       q   q       q   qZ      q    w
# g   qK     Zq   qH      q   qH     Kq   qL      q   q      Lq A q      Lq   q      Kq    w
# sy  q     ZLq   q      Kq t q       q   qZ     Jq   q      Zq   q      Zq   q       q    w
#     q  aaa  q  yq  aaa  q   q  aaa  q  yq  aaa  q   q  aaa  q   q  aaa  q   qJ aaa  q    w
# ...

# %%
def unique_characters(s):
    return set(s)

# Example usage
string = "hello world"
unique_chars = unique_characters(map_data)
print(unique_chars)
# Out:
# {'O', 's', 'q', 'D', 'Z', 'n', '$', 'm', 'M', ',', '¹', 'g', 'H', 'L', 'w', '·', '´', 'A', '/', ' ', 'I', '¿', 'e', 'c', '\xa0', 'G', 'i', 't', 'a', 'l', 'J', 'y', 'K', '°'}

# %%
# Happy that this decoded the hex into a somewhat useable visual :)
# its a little hard to follow as the fonts arent perfectly square.
#Can I now export this as an image?? I.e. a Perfect square reference drawing?
print(square_data_array)
print(square_data_array_2)
# Out:
# ['D                                   t                                                    w', 'wy    t        t            t              y                                             w', 'e       y            y          y      t                      A    A                     w', 'l            y  y        t         y          t         A              A                 w', 'l   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq   qqqqqqqqq    w', 'iy  qJ  H H q y qH  J  Lq   qJ  ZLZ q   qKK    Hq   qH     Jq   qH  H  Jq   qLZ    Hq    w', 'nt  q       q   q      Zq y q       q   q       q   q       q   q       q   qZ      q    w', 'g   qK     Zq   qH      q   qH     Kq   qL      q   q      Lq A q      Lq   q      Kq    w', 'sy  q     ZLq   q      Kq t q       q   qZ     Jq   q      Zq   q      Zq   q       q    w', '    q  aaa  q  yq  aaa  q   q  aaa  q  yq  aaa  q   q  aaa  q   q  aaa  q   qJ aaa  q    w', '    qqqqaqqqq   qqqqaqqqqt  qqqqaqqqq   qqqqaqqqq   qqqq
# ...

# %% [markdown]
# ## Now Render as a single image! (This Worked!!! EPIC! -> Used chatgpt to speed this up. worked great!)

# %%
# Map characters to image file paths
img_map = {
    'q': 'img/castle-wall-32.png',
    'S': 'img/castle-wall-hidden-32.png',
    'P': 'img/castle-floor-32.png',
    'H': 'img/bed-32.png',
    'L': 'img/table-32.png',
    'Z': 'img/chair-32.png',
    'K': 'img/drawers-32.png',
    'J': 'img/heater-32.png',
    '/': 'img/bottle-32.png',
    'G': 'img/cave-32.png',
    ' ': 'img/empty-32.png',
    'a': 'img/empty-32.png', #Seems to denote 'special area'
    '$': 'img/wall-32.png',
    '·': 'img/wall-hidden-32.png',
    'c': 'img/treasure-32.png',
    'Ï': 'img/treasure-32.png',     #Ï on the castle map
    ':': 'img/scroll-32.png',
    'w': 'img/water-32.png',
    'r': 'img/gravestones-32.png',
    '*': 'img/gravestones-black-32.png',
    '1': 'img/water-corner-br-32.png',
    '2': 'img/water-corner-tl-32.png',
    '3': 'img/water-corner-bl-32.png',
    '4': 'img/water-corner-tr-32.png',
    '5': 'img/water-corner-tl-32.png',
    '6': 'img/water-corner-br-32.png',
    '7': 'img/water-corner-tr-32.png',
    '8': 'img/water-corner-bl-32.png',
    'W': 'img/castle-bl-32.png',
    'E': 'img/castle-b-32.png',
    'Y': 'img/castle-br-32.png',
    'R': 'img/castle-b-gate-32.png',
    'Q': 'img/castle-tl-32.png',
    'T': 'img/castle-t-flag-32.png',
    'U': 'img/castle-tr-32.png',
    't': 'img/tree-32.png',
    'A': 'img/palm-32.png',
    'd': 'img/tree-old-32.png',
    'y': 'img/trees-32.png',
    '¨': 'img/trees-hidden-32.png',
    'ª': 'img/glenn1-32.png',
    '£': 'img/glenn2-32.png',
    'B': 'img/temple-32.png',
    'X': 'img/shop-32.png',
    'V': 'img/inn-32.png',
    '+': 'img/house-32.png',
    'C': 'img/house-gnome-32.png',
    'N': 'img/totem-32.png',
    'b': 'img/bridge-32.png',
    'm': 'img/mountain-32.png',
    'F': 'img/mountain-spiked-32.png',
   # '2': 'img/mountain-32.png',            Was wrong on kingdom!
    'D': 'img/mountain-door-32.png',
    'I': 'img/torch-L-32.png',
    'O': 'img/torch-R-32.png',
    '¿': 'img/potion-scorpion-32.png',
    '¹': 'img/potion-spider-32.png',
    '´': 'img/potion-healing-32.png',
    #'´': 'img/potion-magic-32.png',
    '%': 'img/coffin-32.png',
    '@': 'img/key-R-32.png',
    'f': 'img/key-L-32.png',
    '^': 'img/grail-32.png',
}

final_image = create_image_from_ascii(square_data_array_2, img_map, output_size=(2500, 2500), char_size=(50, 50)) # Create the final image from ASCII art and image map
final_image.save(f'{map_and_filename}.png') # Save the image

#NON MAPPED;
## KINGDOM
# Note, Orchid on Kingdom is not mapped :)
